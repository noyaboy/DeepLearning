# %% [markdown]
# # Just an example.You can alter sample code anywhere.

# %% [markdown]
# ## mount your google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# You need to modify this part to the directory where your code is located
# !ls /content/drive/MyDrive/Colab\ Notebooks/DEEP_LEARNING/Lab01
# %cd /content/drive/MyDrive/ColabNotebooks/DEEP_LEARNING/Lab01
# %cd "/content/drive/MyDrive/DL_Lab1/"
# Out:
# /content/drive/MyDrive/ColabNotebooks/DEEP_LEARNING/Lab01

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import model

# %%
#Fix the random seed
np.random.seed(0)

# %% [markdown]
# ## Load the data and label

# %%
train_load = np.loadtxt('./data/fmnist-train.csv',delimiter=',',dtype="int")
test_load = np.loadtxt('./data/fmnist-test.csv',delimiter=',',dtype="int")

np.random.shuffle(train_load)

train_data=train_load[:,1:]
train_label=train_load[:,0]
test_data=test_load
print("shape of train_data: {}".format(train_data.shape))
print("shape of train_label: {}".format(train_label.shape))
print("shape of test_data: {}".format(test_data.shape))
# Out:
# shape of train_data: (60000, 784)
# shape of train_label: (60000,)
# shape of test_data: (10000, 784)

# %% [markdown]
# ## Show the training data

# %%
# uncomment if you want to show the training data
# plt.figure(figsize=(20, 20))
# for index in range(10):
#     image = train_data[index].reshape(28,28)
#     plt.subplot(5, 5, index+1)
#     plt.imshow(image)
# plt.show()

# %%
train_image_num = train_data.shape[0]
test_image_num = test_data.shape[0]
train_data = ((train_data.astype(np.float32) / 255.0))
test_data = ((test_data.astype(np.float32) / 255.0))

print("train_image_num  is : {}".format(train_image_num))
print("test_image_num   is : {}".format(test_image_num))
# Out:
# train_image_num  is : 60000
# test_image_num   is : 10000

# %% [markdown]
# ## Validation image number

# %%
val_image_num=10000

# %% [markdown]
# ## Convert the training labels to one hot vector

# %%
label_temp = np.zeros((train_image_num, 10), dtype = np.float32)
for i in range(train_image_num):
    label_temp[i][train_label[i]] = 1
train_label_onehot = np.copy(label_temp)
print("One-hot training labels shape:",train_label_onehot.shape)
# Out:
# One-hot training labels shape: (60000, 10)

# %% [markdown]
# ## Hyperparameters

# %%
EPOCH = 30
Batch_size = 50 # 10000 should be divisible by batch_size
Learning_rate = 0.03

# %% [markdown]
# ## Training

# %%
import time
from tqdm import tqdm
# please make sure you have place layer.py & network.py in 'model' folder
net = model.Network(config = [32, 64, 128])

train_batch_num = (train_image_num  -  val_image_num  )//Batch_size
val_batch_num = (val_image_num)//Batch_size

# Learning_rate_max = Learning_rate
# Learning_rate_min = Learning_rate_max * 0.01
# total_steps = EPOCH * train_batch_num
# denom = max(1, total_steps - 1)

# global_step = 0

for epoch in range(1, EPOCH+1):
    train_hit = 0
    val_hit = 0
    total_train_loss = 0.0
    total_val_loss = 0.0
    start_time = time.time()
    pred = 0.0

    # Learning_rate = Learning_rate_min + 0.5 * (Learning_rate_max - Learning_rate_min) * (1.0 + np.cos(np.pi * global_step / denom))

    if epoch in [15, 25]:
      Learning_rate *= 0.1

    for it in tqdm(range(train_batch_num), desc=f"Epoch {epoch} - Training"):
        pred, train_loss = net.forward(train_data[it*Batch_size:(it+1)*Batch_size], train_label_onehot[it*Batch_size:(it+1)*Batch_size])
        pred_index = np.argmax(pred, axis=1)
        train_hit += (pred_index==train_label[it*Batch_size:(it+1)*Batch_size]).sum()
        total_train_loss += train_loss

        net.backward()
        net.update(Learning_rate)

        # global_step += 1
    for titt in tqdm(range(val_batch_num), desc=f"Epoch {epoch} - Validation"):
        tit=train_batch_num+titt
        pred, val_loss = net.forward(train_data[tit*Batch_size:(tit+1)*Batch_size], train_label_onehot[tit*Batch_size:(tit+1)*Batch_size], training = False)
        pred_index = np.argmax(pred, axis=1)
        val_hit += (pred_index==train_label[tit*Batch_size:(tit+1)*Batch_size]).sum()
        total_val_loss += val_loss
    end_time = time.time()
    epoch_time = end_time - start_time
    print('Task-1  | Epoch:%3d'%epoch, ' |Lr:%8.4f'%Learning_rate, ' |Train Loss:%8.4f'%(total_train_loss/train_batch_num), ' |Train Acc:%3.4f'%(train_hit/(train_image_num-val_image_num)*100.0)
          , ' |Val Loss:%8.4f'%(total_val_loss/val_batch_num), ' |Val Acc:%3.4f'%(val_hit/val_image_num*100.0), ' |Epoch time:%5.2f'%(epoch_time),' sec')
# Out:
# Epoch 1 - Training: 100%|██████████| 1000/1000 [19:18<00:00,  1.16s/it]
# Epoch 1 - Validation: 100%|██████████| 200/200 [01:34<00:00,  2.11it/s]
# Task-1  | Epoch:  1  |Lr:  0.0300  |Train Loss:  0.8979  |Train Acc:66.6720  |Val Loss:  0.5175  |Val Acc:81.8000  |Epoch time:1253.25  sec
# Epoch 2 - Training: 100%|██████████| 1000/1000 [19:15<00:00,  1.16s/it]
# Epoch 2 - Validation: 100%|██████████| 200/200 [01:35<00:00,  2.10it/s]
# Task-1  | Epoch:  2  |Lr:  0.0300  |Train Loss:  0.5441  |Train Acc:79.7560  |Val Loss:  0.4830  |Val Acc:81.7200  |Epoch time:1251.05  sec
# Epoch 3 - Training: 100%|██████████| 1000/1000 [19:22<00:00,  1.16s/it]
# Epoch 3 - Validation: 100%|██████████| 200/200 [01:36<00:00,  2.08it/s]
# Task-1  | Epoch:  3  |Lr:  0.0300  |Train Loss:  0.4756  |Train Acc:82.2600  |Val Loss:  0.4157  |Val Acc:83.8100  |Epoch time:1258.43  sec
# Epoch 4 - Training: 100%|██████████| 1000/1000 [19:31<00:00,  1.17s/it]
# Epoch 4 - Validation: 100%|██████████| 200/200 [01:34<00:00,  2.11it/s]
# Task-1  | Epoch:  4  |Lr:  0.0300  |Train Loss:  0.4361  |Train Acc:83.6460  |Val Loss:  0.5405  |Val Acc:78.1700  |Epoch time:1265.92  sec
# Epoch 5 - Training: 100%|██████████| 1000/1000 [19:03<00:00,  1.14s/it]
# Epoch 5 - Validation: 100%|██████████| 200/200 [01:35<00:00,  2.10it/s]
# Task-1  | Epoch:  5  |Lr:  0.0300  |Train Loss:  0.4060  |Train Acc:84.8680  |Val Loss:  0.4484  |Val Acc:82.2200  |Epoch time:1239.17  sec
# Epoch 6 - Training: 100%|██████████| 1000/1000 [19:00<00:00,  1.14s/it]
# Epoch 6 - Validation: 100%|██████████| 200/200 [01:34<00:00,  2.12it/s]
# Task-1  | Epoch:  6  |Lr:  0.0300  |Train Loss:  0.3892  |Train Acc:85.5140  |Val Loss:  0.3669  |Val Acc:86.7000  |Epoch time:1235.35  sec
# Epoch 7 - Training: 100%|██████████| 1000/1000 [18:56<00:00,  1.14s/it]
# Epoch 7 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.13it/s]
# Task-1  | Epoch:  7  |Lr:  0.0300  |Train Loss:  0.3752  |Train Acc:86.0140  |Val Loss:  0.3448  |Val Acc:86.9700  |Epoch time:1230.28  sec
# Epoch 8 - Training: 100%|██████████| 1000/1000 [18:52<00:00,  1.13s/it]
# Epoch 8 - Validation: 100%|██████████| 200/200 [01:34<00:00,  2.11it/s]
# Task-1  | Epoch:  8  |Lr:  0.0300  |Train Loss:  0.3654  |Train Acc:86.4920  |Val Loss:  0.3943  |Val Acc:84.4600  |Epoch time:1227.36  sec
# Epoch 9 - Training: 100%|██████████| 1000/1000 [19:05<00:00,  1.15s/it]
# Epoch 9 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.13it/s]
# Task-1  | Epoch:  9  |Lr:  0.0300  |Train Loss:  0.3613  |Train Acc:86.5060  |Val Loss:  0.3741  |Val Acc:86.2500  |Epoch time:1239.18  sec
# Epoch 10 - Training: 100%|██████████| 1000/1000 [18:54<00:00,  1.13s/it]
# Epoch 10 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.13it/s]
# Task-1  | Epoch: 10  |Lr:  0.0300  |Train Loss:  0.3559  |Train Acc:86.7700  |Val Loss:  0.3244  |Val Acc:87.7600  |Epoch time:1228.96  sec
# Epoch 11 - Training: 100%|██████████| 1000/1000 [18:50<00:00,  1.13s/it]
# Epoch 11 - Validation: 100%|██████████| 200/200 [01:34<00:00,  2.12it/s]
# Task-1  | Epoch: 11  |Lr:  0.0300  |Train Loss:  0.3522  |Train Acc:86.9900  |Val Loss:  0.3454  |Val Acc:86.7200  |Epoch time:1224.37  sec
# Epoch 12 - Training: 100%|██████████| 1000/1000 [18:56<00:00,  1.14s/it]
# Epoch 12 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.13it/s]
# Task-1  | Epoch: 12  |Lr:  0.0300  |Train Loss:  0.3520  |Train Acc:86.8980  |Val Loss:  0.3977  |Val Acc:83.7400  |Epoch time:1230.06  sec
# Epoch 13 - Training: 100%|██████████| 1000/1000 [18:55<00:00,  1.14s/it]
# Epoch 13 - Validation: 100%|██████████| 200/200 [01:35<00:00,  2.10it/s]
# Task-1  | Epoch: 13  |Lr:  0.0300  |Train Loss:  0.3507  |Train Acc:86.9560  |Val Loss:  0.3211  |Val Acc:87.8900  |Epoch time:1231.24  sec
# Epoch 14 - Training: 100%|██████████| 1000/1000 [18:54<00:00,  1.13s/it]
# Epoch 14 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.14it/s]
# Task-1  | Epoch: 14  |Lr:  0.0300  |Train Loss:  0.3512  |Train Acc:86.9700  |Val Loss:  0.2735  |Val Acc:90.0200  |Epoch time:1227.71  sec
# Epoch 15 - Training: 100%|██████████| 1000/1000 [18:54<00:00,  1.13s/it]
# Epoch 15 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.13it/s]
# Task-1  | Epoch: 15  |Lr:  0.0030  |Train Loss:  0.2868  |Train Acc:89.4880  |Val Loss:  0.2366  |Val Acc:91.6600  |Epoch time:1228.48  sec
# Epoch 16 - Training: 100%|██████████| 1000/1000 [18:50<00:00,  1.13s/it]
# Epoch 16 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.14it/s]
# Task-1  | Epoch: 16  |Lr:  0.0030  |Train Loss:  0.2752  |Train Acc:89.9220  |Val Loss:  0.2320  |Val Acc:91.7600  |Epoch time:1223.76  sec
# Epoch 17 - Training: 100%|██████████| 1000/1000 [18:36<00:00,  1.12s/it]
# Epoch 17 - Validation: 100%|██████████| 200/200 [01:33<00:00,  2.13it/s]
# Task-1  | Epoch: 17  |Lr:  0.0030  |Train Loss:  0.2737  |Train Acc:89.9460  |Val Loss:  0.2342  |Val Acc:91.8300  |Epoch time:1210.42  sec
# Epoch 18 - Training: 100%|██████████| 1000/1000 [18:30<00:00,  1.11s/it]
# Epoch 18 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.16it/s]
# Task-1  | Epoch: 18  |Lr:  0.0030  |Train Loss:  0.2751  |Train Acc:89.7840  |Val Loss:  0.2369  |Val Acc:91.5300  |Epoch time:1202.78  sec
# Epoch 19 - Training: 100%|██████████| 1000/1000 [18:36<00:00,  1.12s/it]
# Epoch 19 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.16it/s]
# Task-1  | Epoch: 19  |Lr:  0.0030  |Train Loss:  0.2779  |Train Acc:89.8440  |Val Loss:  0.2352  |Val Acc:91.5100  |Epoch time:1209.59  sec
# Epoch 20 - Training: 100%|██████████| 1000/1000 [18:32<00:00,  1.11s/it]
# Epoch 20 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.15it/s]
# Task-1  | Epoch: 20  |Lr:  0.0030  |Train Loss:  0.2822  |Train Acc:89.5880  |Val Loss:  0.2386  |Val Acc:91.6100  |Epoch time:1205.67  sec
# Epoch 21 - Training: 100%|██████████| 1000/1000 [19:24<00:00,  1.16s/it]
# Epoch 21 - Validation: 100%|██████████| 200/200 [01:31<00:00,  2.18it/s]
# Task-1  | Epoch: 21  |Lr:  0.0030  |Train Loss:  0.2856  |Train Acc:89.5160  |Val Loss:  0.2306  |Val Acc:91.8000  |Epoch time:1255.94  sec
# Epoch 22 - Training: 100%|██████████| 1000/1000 [18:32<00:00,  1.11s/it]
# Epoch 22 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.17it/s]
# Task-1  | Epoch: 22  |Lr:  0.0030  |Train Loss:  0.2882  |Train Acc:89.5060  |Val Loss:  0.2276  |Val Acc:92.0600  |Epoch time:1204.52  sec
# Epoch 23 - Training: 100%|██████████| 1000/1000 [18:34<00:00,  1.11s/it]
# Epoch 23 - Validation: 100%|██████████| 200/200 [01:35<00:00,  2.10it/s]
# Task-1  | Epoch: 23  |Lr:  0.0030  |Train Loss:  0.2925  |Train Acc:89.2180  |Val Loss:  0.2254  |Val Acc:92.0800  |Epoch time:1209.79  sec
# Epoch 24 - Training: 100%|██████████| 1000/1000 [18:31<00:00,  1.11s/it]
# Epoch 24 - Validation: 100%|██████████| 200/200 [01:31<00:00,  2.18it/s]
# Task-1  | Epoch: 24  |Lr:  0.0030  |Train Loss:  0.2963  |Train Acc:89.2400  |Val Loss:  0.2353  |Val Acc:91.7800  |Epoch time:1203.06  sec
# Epoch 25 - Training: 100%|██████████| 1000/1000 [18:39<00:00,  1.12s/it]
# Epoch 25 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.17it/s]
# Task-1  | Epoch: 25  |Lr:  0.0003  |Train Loss:  0.2847  |Train Acc:89.5200  |Val Loss:  0.2221  |Val Acc:92.4800  |Epoch time:1212.16  sec
# Epoch 26 - Training: 100%|██████████| 1000/1000 [18:41<00:00,  1.12s/it]
# Epoch 26 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.16it/s]
# Task-1  | Epoch: 26  |Lr:  0.0003  |Train Loss:  0.2909  |Train Acc:89.2700  |Val Loss:  0.2222  |Val Acc:92.4900  |Epoch time:1214.07  sec
# Epoch 27 - Training: 100%|██████████| 1000/1000 [18:47<00:00,  1.13s/it]
# Epoch 27 - Validation: 100%|██████████| 200/200 [01:37<00:00,  2.06it/s]
# Task-1  | Epoch: 27  |Lr:  0.0003  |Train Loss:  0.2988  |Train Acc:89.0660  |Val Loss:  0.2221  |Val Acc:92.6200  |Epoch time:1224.93  sec
# Epoch 28 - Training: 100%|██████████| 1000/1000 [18:34<00:00,  1.11s/it]
# Epoch 28 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.17it/s]
# Task-1  | Epoch: 28  |Lr:  0.0003  |Train Loss:  0.3067  |Train Acc:88.8460  |Val Loss:  0.2231  |Val Acc:92.4900  |Epoch time:1206.53  sec
# Epoch 29 - Training: 100%|██████████| 1000/1000 [18:38<00:00,  1.12s/it]
# Epoch 29 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.15it/s]
# Task-1  | Epoch: 29  |Lr:  0.0003  |Train Loss:  0.3152  |Train Acc:88.3720  |Val Loss:  0.2228  |Val Acc:92.4600  |Epoch time:1211.14  sec
# Epoch 30 - Training: 100%|██████████| 1000/1000 [18:42<00:00,  1.12s/it]
# Epoch 30 - Validation: 100%|██████████| 200/200 [01:32<00:00,  2.16it/s]
# Task-1  | Epoch: 30  |Lr:  0.0003  |Train Loss:  0.3205  |Train Acc:88.2220  |Val Loss:  0.2239  |Val Acc:92.4400  |Epoch time:1214.67  sec

# %% [markdown]
# ## Dump for evaluation (upload your DL-test-predict.csv to kaggle )

# %%
test_pred_list = []
total_test = 0
for tit in range(test_image_num//Batch_size):
    pred, _ = net.forward(test_data[tit*Batch_size:(tit+1)*Batch_size], train_label_onehot[tit*Batch_size:(tit+1)*Batch_size], training = False)
    pred_index = np.argmax(pred, axis=1)
    test_pred_list += pred_index.tolist()
    total_test += Batch_size

print('Please make sure that total test images = 10000')
print(f'Total test images: {total_test} ')

print('Dump file...')
df = pd.DataFrame(test_pred_list, columns=["Category"])
df.to_csv('DL-test-predict.csv', index=True, index_label="Id")
# Out:
# Please make sure that total test images = 10000
# Total test images: 10000
# Dump file...
